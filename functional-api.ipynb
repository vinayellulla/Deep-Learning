# %%
from keras.models import Model

# %%
x = Input(shape=(3,0))

# %%
model = Model(inputs = x, outputs = [output1, output2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model = Model(inputs = x, outputs = [output1, output2])
#
# File /mnt/c/Users/vinay kumar/Desktop/Deep-Learning/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:136, in Functional.__init__(self, inputs, outputs, name, **kwargs)
#     133     inputs, outputs = clone_graph_nodes(inputs, outputs)
#     135 with tracking.DotNotTrackScope():
# --> 136     Function.__init__(self, inputs, outputs, name=name)
#     138 if trainable is not None:
#     139     self.trainable = trainable
#
# File /mnt/c/Users/vinay kumar/Desktop/Deep-Learning/.venv/lib/python3.11/site-packages/keras/src/ops/function.py:90, in Function.__init__(self, inputs, outputs, name)
#      87 def empty_op_outputs(op, *args, **kwargs):
#      88     return [None] * len(tree.flatten(op.output))
# ---> 90 self._run_through_graph(
#      91     [None] * len(self._inputs), call_fn=empty_op_outputs
#      92 )
#      94 # Special handling for NNX to ensure consistent operation instance usage
#      95 if is_nnx_enabled():
#
# File /mnt/c/Users/vinay kumar/Desktop/Deep-Learning/.venv/lib/python3.11/site-packages/keras/src/ops/function.py:221, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     219         path = tree.flatten_with_path(self._outputs_struct)[i][0]
#     220         path = ".".join(str(p) for p in path)
# --> 221         raise ValueError(
#     222             f"Output with path `{path}` is not connected to `inputs`"
#     223         )
#     224     output_tensors.append(tensor_dict[id(x)])
#     226 return tree.pack_sequence_as(self._outputs_struct, output_tensors)
#
# ValueError: Output with path `0` is not connected to `inputs`

# %%
from keras.layers import *

# %%
hidden1 = Dense(128,activation='relu')(x)
hidden2 = Dense(64,activation='relu')(hidden1)

output1 = Dense(1,activation='linear')(hidden1)
output2 = Dense(4,activation='sigmoid')(hidden2)

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
# !pip install pydot
# Out:
# Requirement already satisfied: pydot in ./.venv/lib/python3.11/site-packages (4.0.1)
# Requirement already satisfied: pyparsing>=3.1.0 in ./.venv/lib/python3.11/site-packages (from pydot) (3.3.2)

# %%
from keras.utils import plot_model
plot_model(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 from keras.utils import plot_model
# ----> 2 plot_model(model)
#
# NameError: name 'model' is not defined
